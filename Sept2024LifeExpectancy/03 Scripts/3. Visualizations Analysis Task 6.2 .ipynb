# %% [markdown]
#  # 6.2 Exploring relationships¶
# ### This script contains the following:
# 1. Importing Visualization Libraries and Data
#
# 2. Exploring Relationships
#
# 3. Correlations
#
# 4. Scatterplots
#
# 5. Pair Plots
#
# 6. Categorical Plot

# %% [markdown]
# ## 1. Import Visualizations Libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.7.2'

# %%
# This option ensures the charts you create are displayed in the notebook without the need to "call" them specifically.

# %matplotlib inline

# %%
path =r'/Users/jazmingutierrez/Sept2024LifeExpectancy'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_clean.csv'), index_col = False)

# %%
# checking 
df.head()
# Out:
#    Unnamed: 0          Country Name Country Code                      Region  \
# 0           0           Afghanistan          AFG                  South Asia
# 1           1                Angola          AGO          Sub-Saharan Africa
# 2           2               Albania          ALB       Europe & Central Asia
# 3           3               Andorra          AND       Europe & Central Asia
# 4           4  United Arab Emirates          ARE  Middle East & North Africa
#
#           Income Group  Year  Life Expectancy  Prevalence of Undernourishment  \
# 0           Low income  2001          56.3080                            47.8
# 1  Lower middle income  2001          47.0590                            67.5
# 2  Upper middle income  2001          74.2880                             4.9
# 3          High income  2001          72.1685                             6.2
# 4          High income  2001          74.5440                             2.8
#
# ...

# %% [markdown]
# ## 2. Exploring Relationships

# %%
# Create a subset excluding the "Date" and "No" columns

sub = df[[ 'Life Expectancy','Prevalence of Undernourishment','CO2','Health Expenditure', 'Education Expenditure', 'Unemployment', 'Sanitation', 'Injuries', 'Communicable', 'NonCommunicable']]

# %%
sub
# Out:
#       Life Expectancy  Prevalence of Undernourishment            CO2  \
# 0             56.3080                            47.8     730.000000
# 1             47.0590                            67.5   15960.000000
# 2             74.2880                             4.9    3230.000000
# 3             72.1685                             6.2     520.000000
# 4             74.5440                             2.8   97200.000000
# ...               ...                             ...            ...
# 3301          70.4740                            12.4     209.999993
# 3302          73.3210                             4.4     300.000012
# 3303          64.1310                             6.3  439640.014648
# 3304          63.8860                             6.2    6800.000191
# 3305          61.4900                             6.2   11760.000229
#
#       Health Expenditure  Education Expenditure  Unemployment  Sanitation  \
# ...

# %% [markdown]
# ## 3. Correlations

# %%
# Create a correlation matrix using pandas
sub.corr()
# Out:
#                                 Life Expectancy  \
# Life Expectancy                        1.000000
# Prevalence of Undernourishment        -0.587772
# CO2                                    0.122027
# Health Expenditure                     0.277365
# Education Expenditure                  0.163590
# Unemployment                          -0.064566
# Sanitation                             0.530424
# Injuries                              -0.009992
# Communicable                          -0.220758
# NonCommunicable                        0.040269
#
#                                 Prevalence of Undernourishment       CO2  \
# Life Expectancy                                      -0.587772  0.122027
# Prevalence of Undernourishment                        1.000000 -0.097924
# CO2                                                  -0.097924  1.000000
# Health Expenditure                                   -0.195336  0.110431
# ...

# %%
# Create a correlation heatmap using matplotlib

plt.matshow(sub.corr())
plt.show()

# %%
# Save figure
plt.matshow(sub.corr())
plt.savefig("out.png") 

# This will save the image in the working directory. 
#If you don't know what this directory is the next line will show you how to check

# %%
#current dir
cwd = os.getcwd()
cwd
# Out:
# '/Users/jazmingutierrez/Sept2024LifeExpectancy/03 Scripts'

# %%
# Create a subplot with matplotlib
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# 3. Create a correlation matrix heatmap (colored).
# Discuss what the coefficients in the plot mean in terms of the relationships between the variables.
#
# - NonCommunicable and Injuries has a correlation of 0.95 it is a strong positive relationship, Chronic diseases reflects countries with more injuries.
#
# - CO2 and NonCommunicable has a correlation of 0.82 it is a positive relationship, higher CO2 emissions can be linked to greater burden of NonCommunicalbe diseases.
#
# - Life Expectancy and Sanitation has a moderate positive correlation of 0.53, better acces to sanitation is associated with longer life expectancy.
#
# - Life Expectancy and Prevalence of Undernourishment has a moderate negative correlation of -0.59, higher undernourishment is associated to with shorter life expectancy.
#
# - Prealence of Undernourishment and Sanitation has a moderate negative correlation of -0.40, Poor sanitation is linked to hgiher undernourishment levels.

# %% [markdown]
# ## 4. Scatterplot

# %%
# Create a scatterplot for the "Sanitation" and "Life Expectancy" columns in seaborn

sns.lmplot(x = 'Sanitation', y = 'Life Expectancy', data = df)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "NonCommunicable" and "Injuries" columns in seaborn

sns.lmplot(x = 'Injuries', y = 'NonCommunicable', data = df)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "Life Expectancy" and "Prevalence of Undernourishment" columns in seaborn

sns.lmplot(x = 'Life Expectancy', y = 'Prevalence of Undernourishment', data = df)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "CO2" and "NonCommunicable" columns in seaborn

sns.lmplot(x = 'CO2', y = 'NonCommunicable', data = df)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Create a scatterplot for the "Prevalence of Undernourishment" and "Sanitation" columns in seaborn

sns.lmplot(x = 'Prevalence of Undernourishment', y = 'Sanitation', data = df)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 4. Create a scatterplot (or plots) for the variables with the strongest correlations and examine the nature of their relationships.
# Discuss the output in a markdown cell.
# - NonCommunicable dieases and Injuries Scatterplot has more dots that align with the linear positive line providing a holistic view of the relationship between the two variables.
# - Prevalence of Undernourishment and Sanitation has the weakest relationship of the 4 scatterplots, there is a varience of low undernourishment rates, indicating sanitation is not a uniform factor across these countries, a few have good sanitation despite low undernourishment, while other struggle with poor sanitation.

# %% [markdown]
# ## 5. Pair plot

# %%
# Keep only the variables you want to use in the pair plot

sub_2 = sub[['Life Expectancy', 'NonCommunicable', 'Prevalence of Undernourishment', 'CO2', 'Injuries', 'Sanitation']]

# %%
# Create a pair plot 

g = sns.pairplot(sub_2)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# 5. Create a pair plot of the entire data set.
# Comment on the distribution of the variables and mark variables you’d like to explore further with an explanation of why.
# - Life Expectancy can be explored further in relation to prevalence of undernourishment and sanition, both factors have an impact on life expectancy, they can be used to provide insights to improve health outcomes in countries with lower life expectancy.
# - NonCommunicable is highly skewed with most countries having low levels of non-communicable diseases and a few with high values.

# %% [markdown]
# ## 6. Categorical Plots

# %% [markdown]
# #### Creating a categorical variable that splits "Life Expectancy" column in categories.

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, you can determine sensible categories for the price ranges. 
# You don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['Life Expectancy'], bins = 10, kde = True)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Life Expectancy', ylabel='Count'>

# %%
df.loc[df['Life Expectancy'] < 60, 'LE category'] = 'Low LE'

# %%
df.loc[(df['Life Expectancy'] >=60) & (df['Life Expectancy'] < 75), 'LE category'] = 'Average LE'

# %%
df.loc[df['Life Expectancy'] >= 75, 'LE category'] = 'High LE'

# %%
df['LE category'].value_counts(dropna = False)
# Out:
# LE category
# Average LE    1672
# High LE       1077
# Low LE         557
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country Name', 'Country Code', 'Region', 'Income Group',
#        'Year', 'Life Expectancy', 'Prevalence of Undernourishment', 'CO2',
#        'Health Expenditure', 'Education Expenditure', 'Unemployment',
#        'Sanitation', 'Injuries', 'Communicable', 'NonCommunicable',
#        'Disease Type', 'LE category'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the price categories created above

sns.set(style="ticks")
g = sns.catplot(x="Sanitation", y="Life Expectancy", hue="LE category", data=df)
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Bin the 'Sanitation' column into categories
df['Sanitation Category'] = pd.cut(df['Sanitation'], bins=[0, 25, 50, 75, 100], labels=['Low', 'Medium', 'High', 'Very High'])

# Create the catplot with the binned Sanitation categories
sns.catplot(x="Sanitation Category", y="Life Expectancy", hue="LE category", data=df)

# Add title and labels
plt.title("Sanitation Category vs. Life Expectancy by Life Expectancy Category")
plt.xlabel("Sanitation Category")
plt.ylabel("Life Expectancy")

# Show the plot
plt.show()
# Out:
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/jazmingutierrez/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 6. Create a categorical plot and interpret the results.
#
# Sanitation is a strong predictor of life Expectancy. Countries with higher levels of Sanitation do not have low Life Expectancy. Low and medium sanitation levels have lowe life expectancy category.

# %% [markdown]
# ### 7. Revisit the questions you generated in the previous task and write answers to those you can based on the exploration you’ve conducted so far. Add any new questions that may have arisen based on the early findings in your visual exploration.

# %% [markdown]
# #### Defining Questions:
# 1. Can higher CO2 emissions be associated with lower life expectancy?
# - CO2 and Life Expectancy hasa correlation 0.12 meaning there is no true relationship that could impact each other.
#
# 2. Do countries with the best sanitation levels have lower prevalence of communicable diseases?
# - Sanitation and Communicable diseases has a correlation of -0.2, these two varirables do not correlate and will not impact each other.

# %% [markdown]
# #### New Questions:
# 1. Can higher sanitation levels impact life Expectancy?
# 2. Countries with higher levels of NonCommunicable diseases result in higher injuries?
# 3. Can countries with higher levels of prevalence of undernourishment cause short life expectancy?
# 4. Higher CO2 emissions can be linked to greater burden of NonCommunicalbe diseases?

# %% [markdown]
# ## 8. Define Hypothesis

# %% [markdown]
# Define any hypotheses that you can at this point. You’ll be testing these later on.

# %% [markdown]
# - If sanitation levels are higher, then life expectancy increases.
# - If the levels of Noncommunicable diseases are higher, then the levels of injuries increase.
# - If countries have higher level of prevalence of undernourishment then shorter life expectancy can be expected.

# %%
# fig = g.get_figure()
g.savefig("out.png") 

#  saved in the working directory.
